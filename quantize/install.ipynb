# %% [markdown]
# Clone llama.cpp repository

# %%
# !git clone https://github.com/ggml-org/llama.cpp

# %% [markdown]
# Download lastest build from this https://github.com/ggml-org/llama.cpp/releases
